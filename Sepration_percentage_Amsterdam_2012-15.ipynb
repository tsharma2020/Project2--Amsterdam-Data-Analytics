# %%
import pandas as pd
import numpy as np
#pokemon = pd.read_csv (r'C:\Users\tusha\dataV2-labs\module-1\Dataframe-Calculations\Pokemon.csv')

rawdata1 = pd.read_csv (r'C:\Users\tusha\Project2--Amsterdam-Data-Anlytics\translated files\offered household waste.csv')
rawdata1 = pd.DataFrame(rawdata1)

# %%
rawdata1.head(59)
# Out:
#                    Areas  Perioden  \
# 0               Aalsmeer      2012
# 1               Aalsmeer      2013
# 2               Aalsmeer      2014
# 3               Aalsmeer      2015
# 4                 Almere      2012
# 5                 Almere      2013
# 6                 Almere      2014
# 7                 Almere      2015
# 8             Amstelveen      2012
# 9             Amstelveen      2013
# 10            Amstelveen      2014
# 11            Amstelveen      2015
# 12             Amsterdam      2012
# 13             Amsterdam      2013
# 14             Amsterdam      2014
# 15             Amsterdam      2015
# 16              Beemster      2012
# 17              Beemster      2013
# 18              Beemster      2014
# 19              Beemster      2015
# 20             Beverwijk      2012
# 21             Beverwijk      2013
# 22             Beverwijk      2014
# 23             Beverwijk      2015
# 24              Blaricum      2012
# ...

# %%
rawdata1.columns
# Out:
# Index(['Areas', 'Perioden',
#        'Separation percentage of total household waste [Percentage]',
#        'Total household waste presented [Kilos per inhabitant]'],
#       dtype='object')

# %%
#data[['displ', 'cylinders']] = data[['displ', 'cylinders']].fillna(0)
#null_displ = data[(data['displ'].isnull()==True)]
# null_seperation = rawdata1[(rawdata1['Separation percentage of total household waste [Percentage]'].isnull()==True)]
# null_seperation.head()

# %%
rawdata1['separation percentage'] = rawdata1['Separation percentage of total household waste [Percentage]']
#Total household waste presented [Kilos per inhabitant]

rawdata1['Total waste kilo per inhabb'] = rawdata1['Total household waste presented [Kilos per inhabitant]']
rawdata1.head()
# Out:
#       Areas  Perioden  \
# 0  Aalsmeer      2012
# 1  Aalsmeer      2013
# 2  Aalsmeer      2014
# 3  Aalsmeer      2015
# 4    Almere      2012
#
#   Separation percentage of total household waste [Percentage]  \
# 0                                             60.00%
# 1                                             60.00%
# 2                                             59.00%
# 3                                             59.00%
# 4                                             50.00%
#
#   Total household waste presented [Kilos per inhabitant]  \
# 0                                                536
# 1                                                512
# 2                                                488
# 3                                                495
# 4                                                501
#
#   separation percentage Total waste kilo per inhabb
# 0                60.00%                         536
# 1                60.00%                         512
# ...

# %%
#rawdata1['result_amsterdam'] = np.where((rawdata1['Areas']== "Amsterdam"))

# %%
filtered = rawdata1[(rawdata1["Areas"]=='Amsterdam')]
filtered.head()
# Out:
#         Areas  Perioden  \
# 12  Amsterdam      2012
# 13  Amsterdam      2013
# 14  Amsterdam      2014
# 15  Amsterdam      2015
#
#    Separation percentage of total household waste [Percentage]  \
# 12                                             13.00%
# 13                                             16.00%
# 14                                             17.00%
# 15                                             19.00%
#
#    Total household waste presented [Kilos per inhabitant]  \
# 12                                                433
# 13                                                423
# 14                                                427
# 15                                                399
#
#    separation percentage Total waste kilo per inhabb
# 12                13.00%                         433
# 13                16.00%                         423
# 14                17.00%                         427
# 15                19.00%                         399

# %%
rawdata1.rename(columns={'Areas': 'Area', 'Perioden': 'Year'})
# Out:
#           Area  Year  \
# 0     Aalsmeer  2012
# 1     Aalsmeer  2013
# 2     Aalsmeer  2014
# 3     Aalsmeer  2015
# 4       Almere  2012
# ..         ...   ...
# 131   Zaanstad  2015
# 132  Zandvoort  2012
# 133  Zandvoort  2013
# 134  Zandvoort  2014
# 135  Zandvoort  2015
#
#     Separation percentage of total household waste [Percentage]  \
# 0                                               60.00%
# 1                                               60.00%
# 2                                               59.00%
# 3                                               59.00%
# 4                                               50.00%
# ..                                                 ...
# 131                                             40.00%
# 132                                             34.00%
# 133                                             31.00%
# 134                                             32.00%
# 135                                             35.00%
#
# ...

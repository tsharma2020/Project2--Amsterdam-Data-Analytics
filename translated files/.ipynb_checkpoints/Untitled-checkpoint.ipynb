# %%
import pandas as pd
#pokemon = pd.read_csv (r'C:\Users\tusha\dataV2-labs\module-1\Dataframe-Calculations\Pokemon.csv')

rawdata1 = pd.read_csv (r'C:\Users\tusha\Project2--Amsterdam-Data-Anlytics\translated files\separation percentages.csv')
rawdata1 = pd.DataFrame(rawdata1)

# %%
rawdata1.head(59)
# Out:
#                           Bron: Rijkswaterstaat, CBS. Unnamed: 1  \
# 0          Via: https://afvalmonitor.databank.nl/Jive        NaN
# 1   Over: scheidingspercentages en aangeboden huis...        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6                                            Gebieden   Perioden
# 7                                            Aalsmeer       2012
# 8                                            Aalsmeer       2013
# 9                                            Aalsmeer       2014
# 10                                           Aalsmeer       2015
# 11                                             Almere       2012
# 12                                             Almere       2013
# ...

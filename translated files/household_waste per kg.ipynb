# %%
import pandas as pd
import numpy as np

rawdata2 = pd.read_csv (r'C:\Users\tusha\Project2--Amsterdam-Data-Anlytics\translated files\household waste_kg inhabitant.csv')
rawdata2 = pd.DataFrame(rawdata2)
rawdata2
# Out:
#                                         Unnamed: 0   2014  2015 1)  2016 1)  \
# 0                                              NaN    NaN      NaN      NaN
# 1                         household residual waste  287.1    278.8    256.3
# 2                            bulky household waste   56.3     38.8     66.2
# 3                        renovation residual waste    9.3      5.4      5.1
# 4                              biodegradable waste    0.7      0.5      0.5
# 5                        waste paper and cardboard   27.1     26.6     22.5
# 6                                  packaging glass   21.0     18.5     17.8
# 7                                          textile    2.8      3.1      3.4
# 8                                small toxic waste    0.5      0.6      0.6
# 9                 plastic packaging / PMD fraction    1.7      2.0      2.6
# 10  discarded electrical and electronic appliances    1.9      1.8      1.6
# ...

# %%
rawdata2 = rawdata2.rename(columns={'Unnamed: 0':'Waste category',
                            '2015 1)':'2015', '2016 1)':'2016', '2017 1)':'2017', '2018 1)':'2018'})

# %%
rawdata2
# Out:
#                                     Waste category   2014   2015   2016  \
# 0                                              NaN    NaN    NaN    NaN
# 1                         household residual waste  287.1  278.8  256.3
# 2                            bulky household waste   56.3   38.8   66.2
# 3                        renovation residual waste    9.3    5.4    5.1
# 4                              biodegradable waste    0.7    0.5    0.5
# 5                        waste paper and cardboard   27.1   26.6   22.5
# 6                                  packaging glass   21.0   18.5   17.8
# 7                                          textile    2.8    3.1    3.4
# 8                                small toxic waste    0.5    0.6    0.6
# 9                 plastic packaging / PMD fraction    1.7    2.0    2.6
# 10  discarded electrical and electronic appliances    1.9    1.8    1.6
# 11                              bulky garden waste    2.7    3.5    4.3
# ...

# %%
# # dropping passed values

# %%
rawdata2.drop([0],axis = 0)
# Out:
#                                     Waste category   2014   2015   2016  \
# 1                         household residual waste  287.1  278.8  256.3
# 2                            bulky household waste   56.3   38.8   66.2
# 3                        renovation residual waste    9.3    5.4    5.1
# 4                              biodegradable waste    0.7    0.5    0.5
# 5                        waste paper and cardboard   27.1   26.6   22.5
# 6                                  packaging glass   21.0   18.5   17.8
# 7                                          textile    2.8    3.1    3.4
# 8                                small toxic waste    0.5    0.6    0.6
# 9                 plastic packaging / PMD fraction    1.7    2.0    2.6
# 10  discarded electrical and electronic appliances    1.9    1.8    1.6
# 11                              bulky garden waste    2.7    3.5    4.3
# 12                                           metal    0.8    0.8    0.8
# ...
